# %% [markdown]
# <a href="https://colab.research.google.com/github/sasasa2209/POO/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programacion Orientada a Objetos
# ## Unidad 1
# ### **Programa 1. Introduccion a Python**
# Nombre del alumno: Bruno COrtez Gamboa
#
# Facilitador: Jose Gabrierl Rodriguez Rivas

# %%
# Variables en Python
x = 20
print(x)
# Out:
# 20

# %%
print("La variable x es igual a",x)
# Out:
# La variable x es igual a 20

# %%
x = "Hola"

# %%
print(x*5)
# Out:
# 100

# %%
a = 1000
b = 3000
if a > b:
    print("a es mayor que b")
    print(a,"es mayor que ",b)
else:
    print("a es menor que b")
    print(a,"es menor que",b)

# %%
a = 1
while a < 10:
    print(a)
    print("Dentro del while")
    a = a + 1
print("Fuera del wile")
# Out:
# 1
# Dentro del while
# 2
# Dentro del while
# 3
# Dentro del while
# 4
# Dentro del while
# 5
# Dentro del while
# 6
# Dentro del while
# 7
# Dentro del while
# 8
# Dentro del while
# 9
# Dentro del while
# fuera del wile

# %%
for i in range (1,10):
 print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
